# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("C:/Users/Nanaiah/Desktop/Datasets/IBM.csv")
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
clean_data = data.drop(['EmployeeCount','EmployeeNumber','Over18','StandardHours'],axis=1)
clean_data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  ...  PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# ...

# %%
gender = pd.get_dummies(clean_data['Gender'], drop_first = True,prefix="gender")
attrition = pd.get_dummies(clean_data['Attrition'], drop_first = True,prefix="attrition")

# %%
clean_data = data.drop(['EmployeeCount','EmployeeNumber','Over18','StandardHours'],axis=1)
clean_data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  ...  PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# ...

# %%
clean_data.drop(['Attrition','Gender'],axis=1,inplace=True)

# %%
clean_data= pd.concat([clean_data,gender,attrition],axis =1)
clean_data.head()
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   41      Travel_Rarely       1102                   Sales
# 1   49  Travel_Frequently        279  Research & Development
# 2   37      Travel_Rarely       1373  Research & Development
# 3   33  Travel_Frequently       1392  Research & Development
# 4   27      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    HourlyRate  JobInvolvement  ...  StockOptionLevel TotalWorkingYears  \
# 0          94               3  ...                 0                 8
# ...

# %%
data1 = clean_data.drop(['NumCompaniesWorked','OverTime','PercentSalaryHike','PerformanceRating','RelationshipSatisfaction',
'StockOptionLevel','TotalWorkingYears','TrainingTimesLastYear','WorkLifeBalance','YearsAtCompany','YearsInCurrentRole',
'YearsSinceLastPromotion','YearsWithCurrManager','JobLevel','JobRole','JobSatisfaction','MaritalStatus','MonthlyIncome',               
'MonthlyRate'],axis=1)
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data1.corr()
# Out:
#                               Age  DailyRate  DistanceFromHome  Education  \
# Age                      1.000000   0.010661         -0.001686   0.208034
# DailyRate                0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome        -0.001686  -0.004985          1.000000   0.021042
# Education                0.208034  -0.016806          0.021042   1.000000
# EnvironmentSatisfaction  0.010146   0.018355         -0.016075  -0.027128
# HourlyRate               0.024287   0.023381          0.031131   0.016775
# JobInvolvement           0.029820   0.046135          0.008783   0.042438
# gender_Male             -0.036311  -0.011716         -0.001851  -0.016547
# attrition_Yes           -0.159205  -0.056652          0.077924  -0.031373
#
#                          EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# Age                                     0.010146    0.024287        0.029820
# ...

# %%
sns.heatmap(data1.corr())
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data1)

# %%
sns.countplot(x='DailyRate',hue='attrition_Yes',data=data1)
# Out:
# <AxesSubplot:xlabel='DailyRate', ylabel='count'>

# %%
sns.violinplot(x='attrition_Yes',y='DistanceFromHome',data=data1)
# Out:
# <AxesSubplot:xlabel='attrition_Yes', ylabel='DistanceFromHome'>

# %%
sns.violinplot(x='attrition_Yes',y='Age',data=data1)
# Out:
# <AxesSubplot:xlabel='attrition_Yes', ylabel='Age'>

# %%
sns.violinplot(x='attrition_Yes',y='EnvironmentSatisfaction',data=data1)
# Out:
# <AxesSubplot:xlabel='attrition_Yes', ylabel='EnvironmentSatisfaction'>

# %%
sns.violinplot(x='attrition_Yes',y='JobInvolvement',data=data1)
# Out:
# <AxesSubplot:xlabel='attrition_Yes', ylabel='JobInvolvement'>

# %%
data2=clean_data.drop(['Age','BusinessTravel','DailyRate','Department','DistanceFromHome','Education','EducationField',                 
'EnvironmentSatisfaction','OverTime','TotalWorkingYears','TrainingTimesLastYear','WorkLifeBalance','YearsAtCompany','YearsInCurrentRole',
'YearsSinceLastPromotion','YearsWithCurrManager','RelationshipSatisfaction', 'StockOptionLevel'],axis=1)
data2.head()
# Out:
#    HourlyRate  JobInvolvement  JobLevel                JobRole  \
# 0          94               3         2        Sales Executive
# 1          61               2         2     Research Scientist
# 2          92               2         1  Laboratory Technician
# 3          56               3         1     Research Scientist
# 4          40               3         1  Laboratory Technician
#
#    JobSatisfaction MaritalStatus  MonthlyIncome  MonthlyRate  \
# 0                4        Single           5993        19479
# 1                2       Married           5130        24907
# 2                3        Single           2090         2396
# 3                3       Married           2909        23159
# 4                2       Married           3468        16632
#
#    NumCompaniesWorked  PercentSalaryHike  PerformanceRating  gender_Male  \
# 0                   8                 11                  3            0
# ...

# %%
data2.corr()
# Out:
#                     HourlyRate  JobInvolvement  JobLevel  JobSatisfaction  \
# HourlyRate            1.000000        0.042861 -0.027853        -0.071335
# JobInvolvement        0.042861        1.000000 -0.012630        -0.021476
# JobLevel             -0.027853       -0.012630  1.000000        -0.001944
# JobSatisfaction      -0.071335       -0.021476 -0.001944         1.000000
# MonthlyIncome        -0.015794       -0.015271  0.950300        -0.007157
# MonthlyRate          -0.015297       -0.016322  0.039563         0.000644
# NumCompaniesWorked    0.022157        0.015012  0.142501        -0.055699
# PercentSalaryHike    -0.009062       -0.017205 -0.034730         0.020002
# PerformanceRating    -0.002172       -0.029071 -0.021222         0.002297
# gender_Male          -0.000478        0.017960 -0.039403         0.033252
# attrition_Yes        -0.006846       -0.130016 -0.169105        -0.103481
#
#                     MonthlyIncome  MonthlyRate  NumCompaniesWorked  \
# ...

# %%
sns.pairplot(data2)

# %%
sns.relplot(x='attrition_Yes',y='MonthlyIncome',data=data2)

# %%
sns.violinplot(x='attrition_Yes',y='MonthlyIncome',data=data2)
# Out:
# <AxesSubplot:xlabel='attrition_Yes', ylabel='MonthlyIncome'>

# %%
sns.violinplot(x='attrition_Yes',y='JobLevel',data=data2)
# Out:
# <AxesSubplot:xlabel='attrition_Yes', ylabel='JobLevel'>

# %%
sns.violinplot(x='attrition_Yes',y='JobSatisfaction',data=data2)
# Out:
# <AxesSubplot:xlabel='attrition_Yes', ylabel='JobSatisfaction'>

# %%
sns.violinplot(x='attrition_Yes',y='NumCompaniesWorked',data=data2)
# Out:
# <AxesSubplot:xlabel='attrition_Yes', ylabel='NumCompaniesWorked'>

# %%
data1.columns
# Out:
# Index(['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EnvironmentSatisfaction', 'HourlyRate',
#        'JobInvolvement', 'gender_Male', 'attrition_Yes'],
#       dtype='object')

# %%
data2.columns
# Out:
# Index(['HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole',
#        'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate',
#        'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating',
#        'gender_Male', 'attrition_Yes'],
#       dtype='object')

# %%
data3 = clean_data.drop(['Age','BusinessTravel','DailyRate','Department','DistanceFromHome','Education','EducationField',                 
'EnvironmentSatisfaction','HourlyRate','JobInvolvement','JobLevel','JobRole','JobSatisfaction','MaritalStatus','MonthlyIncome',               
'MonthlyRate','NumCompaniesWorked','PercentSalaryHike','PerformanceRating','gender_Male'],axis=1)
data3.head()
# Out:
#   OverTime  RelationshipSatisfaction  StockOptionLevel  TotalWorkingYears  \
# 0      Yes                         1                 0                  8
# 1       No                         4                 1                 10
# 2      Yes                         2                 0                  7
# 3      Yes                         3                 0                  8
# 4       No                         4                 1                  6
#
#    TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                      0                1               6                   4
# 1                      3                3              10                   7
# 2                      3                3               0                   0
# 3                      3                3               8                   7
# 4                      3                3               2                   2
#
# ...

# %%
data3.corr()
# Out:
#                           RelationshipSatisfaction  StockOptionLevel  \
# RelationshipSatisfaction                  1.000000         -0.045952
# StockOptionLevel                         -0.045952          1.000000
# TotalWorkingYears                         0.024054          0.010136
# TrainingTimesLastYear                     0.002497          0.011274
# WorkLifeBalance                           0.019604          0.004129
# YearsAtCompany                            0.019367          0.015058
# YearsInCurrentRole                       -0.015123          0.050818
# YearsSinceLastPromotion                   0.033493          0.014352
# YearsWithCurrManager                     -0.000867          0.024698
# attrition_Yes                            -0.045872         -0.137145
#
#                           TotalWorkingYears  TrainingTimesLastYear  \
# RelationshipSatisfaction           0.024054               0.002497
# StockOptionLevel                   0.010136               0.011274
# ...

# %%
sns.pairplot(data3)

# %%
sns.relplot(x='attrition_Yes',y='TotalWorkingYears',data=data3)

# %%
sns.relplot(x='attrition_Yes',y='YearsAtCompany',data=data3)

# %%
sns.relplot(x='attrition_Yes',y='YearsInCurrentRole',data=data3)

# %%
sns.relplot(x='attrition_Yes',y='YearsSinceLastPromotion',data=data3)

# %%
sns.relplot(x='attrition_Yes',y='YearsWithCurrManager',data=data3)

# %%
sns.violinplot(x='attrition_Yes',y='StockOptionLevel',data=data3)
# Out:
# <AxesSubplot:xlabel='attrition_Yes', ylabel='StockOptionLevel'>

# %%
sns.violinplot(x='attrition_Yes',y='TotalWorkingYears',data=data3)
# Out:
# <AxesSubplot:xlabel='attrition_Yes', ylabel='TotalWorkingYears'>

# %%
sns.violinplot(x='attrition_Yes',y='YearsAtCompany',data=data3)
# Out:
# <AxesSubplot:xlabel='attrition_Yes', ylabel='YearsAtCompany'>

# %%
sns.violinplot(x='attrition_Yes',y='YearsInCurrentRole',data=data3)
# Out:
# <AxesSubplot:xlabel='attrition_Yes', ylabel='YearsInCurrentRole'>

# %%
sns.violinplot(x='attrition_Yes',y='YearsWithCurrManager',data=data3)
# Out:
# <AxesSubplot:xlabel='attrition_Yes', ylabel='YearsWithCurrManager'>

# %%
sns.set_style('whitegrid')
sns.countplot(x= 'attrition_Yes', data = data3)
# Out:
# <AxesSubplot:xlabel='attrition_Yes', ylabel='count'>

# %%
clean_data.corr()
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# MonthlyIncome             0.497855   0.007707         -0.017014   0.094961
# MonthlyRate               0.028051  -0.032182          0.027473  -0.026084
# ...

# %%
gk = clean_data.groupby('attrition_Yes') 
yes = gk.get_group(1) 
no = gk.get_group(0)

# %%
yes.describe()
# Out:
#               Age    DailyRate  DistanceFromHome   Education  \
# count  237.000000   237.000000        237.000000  237.000000
# mean    33.607595   750.362869         10.632911    2.839662
# std      9.689350   401.899519          8.452525    1.008244
# min     18.000000   103.000000          1.000000    1.000000
# 25%     28.000000   408.000000          3.000000    2.000000
# 50%     32.000000   699.000000          9.000000    3.000000
# 75%     39.000000  1092.000000         17.000000    4.000000
# max     58.000000  1496.000000         29.000000    5.000000
#
#        EnvironmentSatisfaction  HourlyRate  JobInvolvement    JobLevel  \
# count               237.000000  237.000000      237.000000  237.000000
# mean                  2.464135   65.573840        2.518987    1.637131
# std                   1.169791   20.099958        0.773405    0.940594
# min                   1.000000   31.000000        1.000000    1.000000
# ...

# %%
no.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  \
# count  1233.000000  1233.000000       1233.000000  1233.000000
# mean     37.561233   812.504461          8.915653     2.927007
# std       8.888360   403.208379          8.012633     1.027002
# min      18.000000   102.000000          1.000000     1.000000
# 25%      31.000000   477.000000          2.000000     2.000000
# 50%      36.000000   817.000000          7.000000     3.000000
# 75%      43.000000  1176.000000         13.000000     4.000000
# max      60.000000  1499.000000         29.000000     5.000000
#
#        EnvironmentSatisfaction   HourlyRate  JobInvolvement     JobLevel  \
# count              1233.000000  1233.000000     1233.000000  1233.000000
# mean                  2.771290    65.952149        2.770479     2.145985
# std                   1.071132    20.380754        0.692050     1.117933
# min                   1.000000    30.000000        1.000000     1.000000
# ...

# %%
q = data1.groupby('attrition_Yes') 
yes1 = q.get_group(1) 
no1 = q.get_group(0)

# %%
yes1.describe()
# Out:
#               Age    DailyRate  DistanceFromHome   Education  \
# count  237.000000   237.000000        237.000000  237.000000
# mean    33.607595   750.362869         10.632911    2.839662
# std      9.689350   401.899519          8.452525    1.008244
# min     18.000000   103.000000          1.000000    1.000000
# 25%     28.000000   408.000000          3.000000    2.000000
# 50%     32.000000   699.000000          9.000000    3.000000
# 75%     39.000000  1092.000000         17.000000    4.000000
# max     58.000000  1496.000000         29.000000    5.000000
#
#        EnvironmentSatisfaction  HourlyRate  JobInvolvement  gender_Male  \
# count               237.000000  237.000000      237.000000   237.000000
# mean                  2.464135   65.573840        2.518987     0.632911
# std                   1.169791   20.099958        0.773405     0.483031
# min                   1.000000   31.000000        1.000000     0.000000
# ...

# %%
no1.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  \
# count  1233.000000  1233.000000       1233.000000  1233.000000
# mean     37.561233   812.504461          8.915653     2.927007
# std       8.888360   403.208379          8.012633     1.027002
# min      18.000000   102.000000          1.000000     1.000000
# 25%      31.000000   477.000000          2.000000     2.000000
# 50%      36.000000   817.000000          7.000000     3.000000
# 75%      43.000000  1176.000000         13.000000     4.000000
# max      60.000000  1499.000000         29.000000     5.000000
#
#        EnvironmentSatisfaction   HourlyRate  JobInvolvement  gender_Male  \
# count              1233.000000  1233.000000     1233.000000  1233.000000
# mean                  2.771290    65.952149        2.770479     0.593674
# std                   1.071132    20.380754        0.692050     0.491346
# min                   1.000000    30.000000        1.000000     0.000000
# ...

# %%
e = data2.groupby('attrition_Yes') 
yes2 = e.get_group(1) 
no2 = e.get_group(0)

# %%
yes2.describe()
# Out:
#        HourlyRate  JobInvolvement    JobLevel  JobSatisfaction  MonthlyIncome  \
# count  237.000000      237.000000  237.000000       237.000000     237.000000
# mean    65.573840        2.518987    1.637131         2.468354    4787.092827
# std     20.099958        0.773405    0.940594         1.118058    3640.210367
# min     31.000000        1.000000    1.000000         1.000000    1009.000000
# 25%     50.000000        2.000000    1.000000         1.000000    2373.000000
# 50%     66.000000        3.000000    1.000000         3.000000    3202.000000
# 75%     84.000000        3.000000    2.000000         3.000000    5916.000000
# max    100.000000        4.000000    5.000000         4.000000   19859.000000
#
#         MonthlyRate  NumCompaniesWorked  PercentSalaryHike  PerformanceRating  \
# count    237.000000          237.000000         237.000000         237.000000
# mean   14559.308017            2.940928          15.097046           3.156118
# ...

# %%
no2.describe()
# Out:
#         HourlyRate  JobInvolvement     JobLevel  JobSatisfaction  \
# count  1233.000000     1233.000000  1233.000000      1233.000000
# mean     65.952149        2.770479     2.145985         2.778589
# std      20.380754        0.692050     1.117933         1.093277
# min      30.000000        1.000000     1.000000         1.000000
# 25%      48.000000        2.000000     1.000000         2.000000
# 50%      66.000000        3.000000     2.000000         3.000000
# 75%      83.000000        3.000000     3.000000         4.000000
# max     100.000000        4.000000     5.000000         4.000000
#
#        MonthlyIncome   MonthlyRate  NumCompaniesWorked  PercentSalaryHike  \
# count    1233.000000   1233.000000          1233.00000        1233.000000
# mean     6832.739659  14265.779400             2.64558          15.231144
# std      4818.208001   7102.260749             2.46009           3.639511
# min      1051.000000   2094.000000             0.00000          11.000000
# ...

# %%
r = data3.groupby('attrition_Yes') 
yes3 = r.get_group(1) 
no3 = r.get_group(0)

# %%
yes3.describe()
# Out:
#        RelationshipSatisfaction  StockOptionLevel  TotalWorkingYears  \
# count                237.000000        237.000000         237.000000
# mean                   2.599156          0.527426           8.244726
# std                    1.125437          0.856361           7.169204
# min                    1.000000          0.000000           0.000000
# 25%                    2.000000          0.000000           3.000000
# 50%                    3.000000          0.000000           7.000000
# 75%                    4.000000          1.000000          10.000000
# max                    4.000000          3.000000          40.000000
#
#        TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# count             237.000000       237.000000      237.000000
# mean                2.624473         2.658228        5.130802
# std                 1.254784         0.816453        5.949984
# min                 0.000000         1.000000        0.000000
# ...

# %%
no3.describe()
# Out:
#        RelationshipSatisfaction  StockOptionLevel  TotalWorkingYears  \
# count               1233.000000       1233.000000        1233.000000
# mean                   2.733982          0.845093          11.862936
# std                    1.071603          0.841985           7.760719
# min                    1.000000          0.000000           0.000000
# 25%                    2.000000          0.000000           6.000000
# 50%                    3.000000          1.000000          10.000000
# 75%                    4.000000          1.000000          16.000000
# max                    4.000000          3.000000          38.000000
#
#        TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# count            1233.000000      1233.000000     1233.000000
# mean                2.832928         2.781022        7.369019
# std                 1.293585         0.681907        6.096298
# min                 0.000000         1.000000        0.000000
# ...
