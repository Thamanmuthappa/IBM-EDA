# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("C:/Users/Nanaiah/Desktop/Datasets/IBM.csv")
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
data.shape
# Out:
# (1470, 35)

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
data.nunique()
# Out:
# Age                           43
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1470
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyIncome               1349
# MonthlyRate                 1427
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# ...

# %%
data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
clean_data = data.drop(['EmployeeCount','EmployeeNumber','Over18','StandardHours'],axis=1)
clean_data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  ...  PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# ...

# %%
clean_data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810   802.485714          9.192517     2.912925
# std       9.135373   403.509100          8.106864     1.024165
# min      18.000000   102.000000          1.000000     1.000000
# 25%      30.000000   465.000000          2.000000     2.000000
# 50%      36.000000   802.000000          7.000000     3.000000
# 75%      43.000000  1157.000000         14.000000     4.000000
# max      60.000000  1499.000000         29.000000     5.000000
#
#        EnvironmentSatisfaction   HourlyRate  JobInvolvement     JobLevel  \
# count              1470.000000  1470.000000     1470.000000  1470.000000
# mean                  2.721769    65.891156        2.729932     2.063946
# std                   1.093082    20.329428        0.711561     1.106940
# min                   1.000000    30.000000        1.000000     1.000000
# ...

# %%
clean_data.corr()
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# MonthlyIncome             0.497855   0.007707         -0.017014   0.094961
# MonthlyRate               0.028051  -0.032182          0.027473  -0.026084
# ...

# %% [markdown]
# First using "countplot"
# To compare Attrition to attributes with less than 10 unique values.
# The reason why I limited the value to 10 was as any value above the same would be very hard to analyse

# %%
sns.set_style('whitegrid')
sns.countplot(x= 'Attrition', data = clean_data)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %% [markdown]
# As we can see from the above plot, the attrition count of IBM is over 200.

# %%
sns.set_style('whitegrid')
sns.countplot(x= 'Attrition', hue= "Department",data = clean_data)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %% [markdown]
# In the above plots I have analysed the attrition within several departments of the company.
# As we can see,
# The R&D department had around 1000 employees and have retained about 85% of their employees, i.e, Attrition = 15%.
# The Sales department had around 450 employees and have retained about 78% of their employees, i.e, Attrition = 22%.
# The HR department had around 50 employees and have retained about 90% of their employees, i.e, Attrition = 10%.
#
# So, we can conclude that the department with the highest attrition was "Sales".

# %%
sns.set_style('whitegrid')
sns.countplot(x= 'Attrition', hue= "Gender",data = clean_data)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %% [markdown]
# In the above plots I have compared the attrition between the male and female employees.
# As we can see,
# The company had around 900 male employees and have retained about 83%, i.e, Attrition = 17%.
# The company had around 600 female employees and have retained about 75%, i.e, Attrition = 25%.
#
# So, we can conclude that the more male employees were retained by the company.
#
# However, the male to female ratio remains unchanged at 3:2 (initially 900:600, which then became 750:500)

# %%
sns.set_style('whitegrid')
sns.countplot(x= 'Attrition', hue= "JobLevel",data = clean_data)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %% [markdown]
# In the above plots I have analysed the attrition within several "Job Levels" of the company.
# As we can see,
# The company had around 550 employees at level 1 and have retained about 73%, i.e, Attrition = 27%.
# The company had around 525 employees at level 2 and have retained about 90.5%, i.e, Attrition = 9.5%.
# The company had around 220 employees at level 3 and have retained about 82%, i.e, Attrition = 18%.
# The company had around 105 employees at level 4 and have retained about 96%, i.e, Attrition = 5%.
# The company had around 60  employees at level 5 and have retained about 92%, i.e, Attrition = 8%.
#
# So, we can conclude that the Level with the highest attrition was "Level 1" followed by "Level 3".

# %%
sns.set_style('whitegrid')
sns.countplot(x= 'Attrition', hue= "JobSatisfaction",data = clean_data)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %% [markdown]
# In the above plots I have compared the attrition with "Job Satisfaction Levels" of various employees.
# As we can see,
# The company had around 280 employees at level 1 and have retained about 78.5%, i.e, Attrition = 21.5%.
# The company had around 270 employees at level 2 and have retained about 83%, i.e, Attrition = 17%.
# The company had around 420 employees at level 3 and have retained about 86%, i.e, Attrition = 14%.
# The company had around 450 employees at level 4 and have retained about 89%, i.e, Attrition = 11%.
#
# So, we can conclude that the Level with the highest attrition was "Level 1" followed by "Level 2".
# So, it is fair to say that employees with higher job satisfaction have lower tendancies to leave the job, thus reducing attrition.

# %% [markdown]
# NOTE:
# JobSatisfaction Levels
# 1 = 'Low'
# 2 = 'Medium'
# 3 = 'High'
# 4 = 'Very High'

# %%
sns.set_style('whitegrid')
sns.countplot(x= 'Attrition', hue= "WorkLifeBalance",data = clean_data)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %% [markdown]
# In the above plots I have compared the attrition with "Work-Life Balance Levels" of various employees.
# As we can see,
# The company had around 60  employees at level 1 and have retained about 83%, i.e, Attrition = 17%.
# The company had around 325 employees at level 2 and have retained about 84.5%, i.e, Attrition = 15.5%.
# The company had around 875 employees at level 3 and have retained about 86%, i.e, Attrition = 14%.
# The company had around 150 employees at level 4 and have retained about 83%, i.e, Attrition = 17%.
#
# So, we can conclude that the Level with the highest attrition was "Level 4" followed by "Level 2" {sample size of Level  is too small}.

# %% [markdown]
# Note:
# WorkLifeBalance
# 1 'Bad'
# 2 'Good'
# 3 'Better'
# 4 'Best'

# %%
sns.set_style('whitegrid')
sns.countplot(x= 'Attrition', hue= "StockOptionLevel",data = clean_data)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x= 'Attrition', hue= "MaritalStatus",data = clean_data)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x= 'Attrition', hue= "RelationshipSatisfaction",data = clean_data)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x= 'Attrition', hue= "PerformanceRating",data = clean_data)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x= 'Attrition', hue= "BusinessTravel",data = clean_data)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x= 'Attrition', hue= "Education",data = clean_data)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x= 'Attrition', hue= "EducationField",data = clean_data)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x= 'Attrition', hue= "OverTime",data = clean_data)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x= 'Attrition', hue= "JobRole",data = clean_data)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x= 'Attrition', hue= "TrainingTimesLastYear",data = clean_data)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %%
sns.distplot(clean_data['MonthlyIncome'],kde = False, bins = 40)
# Out:
# <AxesSubplot:xlabel='MonthlyIncome'>

# %%
sns.distplot(clean_data['TotalWorkingYears'],kde = False, bins = 40)
# Out:
# <AxesSubplot:xlabel='TotalWorkingYears'>

# %%
sns.distplot(clean_data['YearsAtCompany'],kde = False, bins = 40)
# Out:
# <AxesSubplot:xlabel='YearsAtCompany'>

# %%
sns.jointplot(x="attrition_Yes",y="MonthlyIncome",data=clean_data, kind = 'reg')

# %%
sns.boxplot(x='attrition_Yes',y='DistanceFromHome',data=clean_data)
# Out:
# <AxesSubplot:xlabel='attrition_Yes', ylabel='DistanceFromHome'>

# %%
sns.boxplot(x='Attrition',y='MonthlyIncome',data=clean_data)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='MonthlyIncome'>

# %%
gender = pd.get_dummies(clean_data['Gender'], drop_first = True,prefix="gender")
attrition = pd.get_dummies(clean_data['Attrition'], drop_first = True,prefix="attrition")

# %%
clean_data = data.drop(['EmployeeCount','EmployeeNumber','Over18','StandardHours'],axis=1)
clean_data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  ...  PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# ...

# %%
clean_data.drop(['Attrition','Gender'],axis=1,inplace=True)

# %%
clean_data= pd.concat([clean_data,gender,attrition],axis =1)

# %%
clean_data.head()
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   41      Travel_Rarely       1102                   Sales
# 1   49  Travel_Frequently        279  Research & Development
# 2   37      Travel_Rarely       1373  Research & Development
# 3   33  Travel_Frequently       1392  Research & Development
# 4   27      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    HourlyRate  JobInvolvement  ...  StockOptionLevel TotalWorkingYears  \
# 0          94               3  ...                 0                 8
# ...

# %%
data1 = clean_data.drop(['NumCompaniesWorked','OverTime','PercentSalaryHike','PerformanceRating','RelationshipSatisfaction',
'StockOptionLevel','TotalWorkingYears','TrainingTimesLastYear','WorkLifeBalance','YearsAtCompany','YearsInCurrentRole',
'YearsSinceLastPromotion','YearsWithCurrManager'],axis=1)

# %%
data1.head()
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   41      Travel_Rarely       1102                   Sales
# 1   49  Travel_Frequently        279  Research & Development
# 2   37      Travel_Rarely       1373  Research & Development
# 3   33  Travel_Frequently       1392  Research & Development
# 4   27      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    HourlyRate  JobInvolvement  JobLevel                JobRole  \
# 0          94               3         2        Sales Executive
# ...

# %%
data1.corr()
# Out:
#                               Age  DailyRate  DistanceFromHome  Education  \
# Age                      1.000000   0.010661         -0.001686   0.208034
# DailyRate                0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome        -0.001686  -0.004985          1.000000   0.021042
# Education                0.208034  -0.016806          0.021042   1.000000
# EnvironmentSatisfaction  0.010146   0.018355         -0.016075  -0.027128
# HourlyRate               0.024287   0.023381          0.031131   0.016775
# JobInvolvement           0.029820   0.046135          0.008783   0.042438
# JobLevel                 0.509604   0.002966          0.005303   0.101589
# JobSatisfaction         -0.004892   0.030571         -0.003669  -0.011296
# MonthlyIncome            0.497855   0.007707         -0.017014   0.094961
# MonthlyRate              0.028051  -0.032182          0.027473  -0.026084
# Male                    -0.036311  -0.011716         -0.001851  -0.016547
# ...

# %%
sns.heatmap(data1.corr())
# Out:
# <AxesSubplot:>

# %%
data2= clean_data.drop(['Age','BusinessTravel','DailyRate','Department','DistanceFromHome','Education','EducationField',                 
'EnvironmentSatisfaction','HourlyRate','JobInvolvement','JobLevel','JobRole','JobSatisfaction','MaritalStatus','MonthlyIncome',               
'MonthlyRate'],axis=1)
data2.head()
# Out:
#    NumCompaniesWorked OverTime  PercentSalaryHike  PerformanceRating  \
# 0                   8      Yes                 11                  3
# 1                   1       No                 23                  4
# 2                   6      Yes                 15                  3
# 3                   1      Yes                 11                  3
# 4                   9       No                 12                  3
#
#    RelationshipSatisfaction  StockOptionLevel  TotalWorkingYears  \
# 0                         1                 0                  8
# 1                         4                 1                 10
# 2                         2                 0                  7
# 3                         3                 0                  8
# 4                         4                 1                  6
#
#    TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# ...

# %%
data2.corr()
# Out:
#                           NumCompaniesWorked  PercentSalaryHike  \
# NumCompaniesWorked                  1.000000          -0.010238
# PercentSalaryHike                  -0.010238           1.000000
# PerformanceRating                  -0.014095           0.773550
# RelationshipSatisfaction            0.052733          -0.040490
# StockOptionLevel                    0.030075           0.007528
# TotalWorkingYears                   0.237639          -0.020608
# TrainingTimesLastYear              -0.066054          -0.005221
# WorkLifeBalance                    -0.008366          -0.003280
# YearsAtCompany                     -0.118421          -0.035991
# YearsInCurrentRole                 -0.090754          -0.001520
# YearsSinceLastPromotion            -0.036814          -0.022154
# YearsWithCurrManager               -0.110319          -0.011985
# Male                               -0.039147           0.002733
# Yes                                 0.043494          -0.013478
#
# ...

# %%
sns.heatmap(data2.corr())
